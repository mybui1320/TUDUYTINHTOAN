# %% [markdown]
# ## Bài 1
# Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu vi của nó.

# %%
a= float(input())
b= float(input())
S= a*b
p= (a+b)*2
print(S,p)

# %% [markdown]
# ## Bài 2:
# Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
r= float(input())
s=3.14*r*r
p= 2*3.14*r
print(s, p)

# %% [markdown]
# ## Bài 3 :
# Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểm tra xem nó có thể là độ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn hình.

# %%
a,b,c= map(int, input().split())
p=(a+b+c)/2
S=(p*(p-a)*(p-b)*(p-c))**0.5
C= a+b+c
if a==b==c and a!=0 and b!=0 and c!=0:
    print(f"Tam giác đều\nDiện tích:{s}\nChu vi:{C}")
elif (a==b or a==c or b==c) and a!=0 and b!=0 and c!=0:
    print(f"Tam giác cân\nDiện tích:{s}\nChu vi:{C}")
elif a+b>c and b+c>a and c+a>b:
    print(f"Tam giác thường\nDiện tích:{s}\nChu vi:{C}")
else:
    print("Không phải tam giác")

# %% [markdown]
# ## Bài 4:
# Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a=float(input("y=ax+b\na="))
b=float(input("b="))
x= -b/a
print("Giá trị của x=", round(x,2))

# %% [markdown]
# ## Bài 5:
# Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a,b,c=map(float, input().split())
denta= b*b-4*a*c
x1= (b+denta**0.5)/(2*a)
x2= (b-denta**0.5)/(2*a)
print("x1=", x1)
print("x2=", x2)

# %% [markdown]
# ## Bài 6:
# Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a,b,c,d= map(int, input().split())
_max=a
if b> _max:
    _max=b
if c> _max:
    _max=c
if d> _max:
    _max=d
    
print(_max)

# %% [markdown]
# ## Bài 7:
# Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a,b,c,d= map(int, input().split())
_min=a
if b< _min:
    _min=b
if b< _min:
    _min=c
if d<_min:
    _min=d
    
print(_min)

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# - ax + by = m
# - cx + dy = n

# %%
a,b,c,d,m,n= map(float,input().split())
x=(m-b*n/d)/(a-b*c/d)
y=(m-n*a/c)/(-a*d/c+b)
print(x,y)

# %% [markdown]
# ## Bài 9:
# Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x= float(input())
h= x/3600
p=x/60
print(f"Giờ: {h}, phút: {p}, giây: {x}")

# %% [markdown]
# ## Bài 10:
# Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vào một điểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
a,b,R= map(float, input().split())
x,y= map(float, input().split())
if (x-a)**2+ (y-b)**2<=(R**2):
    print("Điểm A(x,y) thuộc đường tròn")
else:
    print("Điểm A(x,y) không thuộc đường tròn")

# %% [markdown]
# ## Bài 11:
# Tính x^y (Với x, y là số thực).

# %%
x=float(input())
y=float(input())
p= x**y
print(p)
