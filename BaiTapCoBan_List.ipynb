# %% [markdown]
# ### Bài 1: Tìm số lớn nhất của 1 list

# %%
lst= list(map(int, input().split()))
if lst:
    ans =lst[0]
    for i in lst:
        if i> ans:
            ans=i

    print(ans)

# %% [markdown]
# ### Bài 2: Tìm số nhỏ nhất của 1 list

# %%
lst= list(map(int, input().split()))
if lst:
    ans =lst[0]
    for i in lst:
        if i< ans:
            ans=i

    print(ans)

# %% [markdown]
# ### Bài 2b: Tìm số nhỏ nhất của 1 list và vị trí của nó, nếu có nhiều số nhỏ nhất bằng nhau thì lấy chỉ số đầu tiên (nhỏ nhất)
# 10 0 0 12 34 5 6 7  8 89
# 0 1

# %%
# lst= list(map(int, input().split()))
# if lst:
#     ans =lst[0]
#     for i in lst:
#         if i< ans:
#             ans=i
#     index_pos= lst.index(ans)
#     print(ans, index_pos)


def min_and_pos(lst):
    if lst:
        min_value =lst[0]
        min_pos= 1
        for i , x in enumerate(lst, 1):
            if x< min_value:
                min_value =x
                min_pos= i
        return min_value, min_pos

lst= list(map(int, input().split()))    
print(min_and_pos(lst))
# Out:
# (0, 2)

# %% [markdown]
# ### Bài 3: Tìm giá trị trung bình của 1 list, nếu ko có số dương nào trả về invalid

# %%
# lst= list(map(int, input().split()))
# if lst:
#     s=0
#     cnt=0
#     for i in lst:
#         if i>0:
#             s+=i
#             cnt+=1
#             sum=s/cnt
#         else:
#             sum='invalid'
        
#     print(sum)

def Average_lst(lst):
    if lst:
        s=0
        cnt=0
        for i in lst:
            if i>0:
                s+=i
                cnt+=1
                sum=s/cnt
            else:
                sum='invalid'
        return sum

lst= list(map(int, input().split()))
print(Average_lst(lst))
# Out:
# 5.0

# %% [markdown]
# ### Bài 4: Kiểm tra một list số nguyên có phải là đối xứng hay không

# %%
# if lst== lst[::-1]:

def ktra_doi_xung(lst):
    if lst:
        l=len(lst)
        for i in range (len(l//2)):
            if l[i]!= lst[l-1-i]:
                return False
        return True
    return False

lst= list(map(int, input().split()))
print(ktra_doi_xung(lst))

# %% [markdown]
# ### Bài 5: Đưa tất cả các số bằng 0 trong list về đầu của list. Các số khác không thay đổi thứ tự trước sau
# 3 4 6 7 1 9 0 0 23 0 0 34 67 89
# 0 0 0 0 3 4 6 7 1 9 23 34 67 89

# %%
def move_zero_to_first(lst):
    if lst:
        for i , x in enumerate(lst):
            if x==0:
                lst.pop(i)
                lst.insert(0,0)
        return lst
    return None
lst= list(map(int, input().split()))
print(move_zero_to_first(lst))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 9
#       5                 lst.pop(i)
#       6                 lst.insert(0,0)
#       7         return lst
#       8     return None
# ----> 9 assert move_zero_to_first([3, 4, 0, 0, 23, 0, 0, 0, 34, 67, 89]) == [0, 0, 0, 0, 3, 4, 23, 34, 67, 89]
#      10 print("accepted")
#
# AssertionError:

# %% [markdown]
# ### Bài 6: Xóa tất cả các số giống nhau trong list, Các số khác giữ nguyên vị trí trước sau

# %%
def unique_array(lst):
    if lst:
        ans= []
        for x in lst:
            if x not in ans:
                ans.append()
        return ans
    return None

lst= list(map(int, input().split()))
print(unique_array(lst))

# %% [markdown]
# ### Bài 7: Kiểm tra một list số nguyên có phải là dãy tăng, dãy giảm hay vô danh
# 1 3 5 6 7 8 9: Tang
# 9 8 7 6 5 4 0: Giam
# 1 2 3 7 1 0 2: Vo danh
# 1 2 2 4 5 7: Vo danh

# %%
lst= list(map(int, input().split()))
tang= True
giam=True
for i in range(len(lst)-1):
    if lst[i]>= lst[i+1]:
        tang=False
    if lst[i]<=lst[i+1]:
        giam=False

if tang:
    print("tang")
elif giam:
    print("giam")
else:
    print("vo danh")

# %% [markdown]
# ### Bài 8: Kiểm tra một list số nguyên có phải là ziczac khong
# 1 3 2 5 2 8 7 9 2 100: ziczac
# 34 2 56 7 90 20 30 7 120: ziczac
# tăng giảm tăng giảm ( lên xuống)

# %%
lst= list(map(int, input().split()))
ziczac= True
for i in range (len(lst)-2):
    if (lst[i]-lst[i+1])*(lst[i+1]-lst[i+2])>=0:
        ziczac= False

if ziczac:
    print("ziczac")
else:
    print("khong")

# %% [markdown]
# ### Bài 9: Tìm và in ra tất cả các vị trí của số nguyên k trong một danh sách số nguyên cho trước. Nếu không có k trong ds thì in ra "-1".
# VD: k = 3, [1,3,4,4,3,3,4,3,6,1] => k xuất hiện tại các vị trí (trả về 1 list) [1, 4, 5, 7]
# k = 10, [1,3,4,4,3,3,4,3,6,1] => k không xuất hiện trong ds => trả về "-1"

# %%
a = list(map(int, input().split()))
k = int(input())

found = False

for i in range(len(a)):
    if a[i] == k:
        print(i , end=" ")
        found = True

if not found:
    print(-1)

# %% [markdown]
# ### Bài 10:
# Nhập vào tên một người, in ra kí tự đầu tiên và kí tự cuối cùng của tên đó.
# VD: "Nguyen Ai Quoc" => ["N", "c"]

# %%
s = input().strip()
print([s[0], s[-1]])
