# %% [markdown]
# Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n= int(input())
print(2*n)

# %% [markdown]
# Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2 chữ số phần thập phân.

# %%
a= float(input())
b= float(input())
S= 3.14*a/2*a/2
p= a*b-S
print(f"{p:.2f}")

# %% [markdown]
# Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem trước cấu trúc lựa chọn: if….else, ma)

# %%
c= input()
if c.isupper():
    print(c.lower())
elif c.islower():
    print(c.upper())

# %% [markdown]
# Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c} không phải là kí tự alphabet.

# %%
c= str(input())
if c.isupper():
    print(f"{c} là kí tự alphabet")
elif c.islower():
    print(f"{c} là kí tự alphabet")
else:
    print(f"{c} không phải là kí tự alphabet")

# %% [markdown]
# Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c= input()
if c=='A':
    print('z')
elif c.islower():
    print("False")
elif c.isupper():
        x= ord(c)+31
        print(chr(x))

# %% [markdown]
# Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không, nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
p=(a+b+c)/2
S=(p*(p-a)*(p-b)*(p-c))**0.5
if a+b>c and b+c>a and c+a>b:
    print(f"{S:.1f}")
else:
    print("Không phải 3 cạnh của tam giác")

# %% [markdown]
# Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và thứ chín của chuỗi này.

# %%
s= str(input())
if len(s)>= 20:
    print(s[4], s[8])
else:
    print("Error")

# %% [markdown]
# Bài 8:

# %%
a= str(input("Tên chủ hộ:"))
b= int(input("Số điện kế tháng trước:"))
c= int(input("Số điện kế tháng này:"))
d= c-b
print("Họ và tên:",a)
if d <=50:
    p= (c-b)*1.984*1.08
    print("Tiền phải trả là:",f"{p:.3f}")
elif 51 <= (c-b) <=100:
    p=(50*1.984+(d-50)*2.050)*1.08
    print("Tiền phải trả là:",f"{p:.3f}")
elif 101<=(c-b)<=200:
    p=(50*1.984+50*2.050+(d-100)*2.38)*1.08
    print("Tiền phải trả là:",f"{p:.3f}"p)
elif 201<= (c-b)<=300:
    p=(50*1.984+50*2.050+100*2.38+(d-200)*2.998)*1.08
    print("Tiền phải trả là:",f"{p:.1f}")
elif 301<= (c-b)<=400:
    p=(50*1.984+50*2.050+100*2.38+100*2.998+(d-300)*3.35)*1.08
    print("Tiền phải trả là:",f"{p:.3f}")
else:
     p=(50*1.984+50*2.05+100*2.38+100*2.998+100*3.35+(d-400)*3.46)*1.08
     print("Tiền phải trả là:",f"{p:.3f}")

# %% [markdown]
# 1. Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó
# là số chẵn hay số lẻ

# %%
n= int(input())
if n%2 ==0:
    print("Số chẵn")
elif n%2 ==1:
    print("Số lẻ")

# %% [markdown]
# 2. Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
s=int(input())
if s[-1]=='5':
    print("True")
else:
    print("False")

# %% [markdown]
# Kiểm tra số có chia hết cho 3 và 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có chia hết cho 3 và 5 không, nếu đúng in ra “True”, nếu sai in ra“False”.

# %%
x= int(input())
if x%3==0 or x%5==0:
    print("True")
else:
    print("False")

# %% [markdown]
# 4. Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
since= int(input())
age= 2026- since
if age >= 18:
    print("age =", age)
    print("Đủ tuỏi bầu cử")
else:
    print("age =", age)
    print("Không đủ tuổi bầu cử")

# %% [markdown]
# 5. So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo nếu hai số bằng nhau.

# %%
a= input()
b= input()
if a>b:
    print(a)
elif b>a:
    print(b)
else:
    print("Hai số bằng nhau")

# %% [markdown]
# 6. Kiểm tra ký tự nhập vào là chữ hay số: Viết chương trình nhập một ký tự, kiểm tra xem ký tự đó là chữ cái hay số.

# %%
x=input()
if x.isalpha():
    print("Chữ cái")
elif x.isdigit():
    print("Chữ số")
# Out:
# Chữ số

# %% [markdown]
# 7. Bài tập 5: Tính điểm học lực
# Nhập điểm (0-10), phân loại học lực theo quy tắc: >=8: Giỏi; >=6.5 và <8: Khá; >=5 và <6.5: Trung bình; <5: Yếu

# %%
điểm = float(input("Nhập điểm từ 0-10:"))
if 8 <= điểm <= 10:
    print("Học lực: Giỏi")
elif 6<= điểm < 8:
    print("Học lực: Khá")
elif 5 <= điểm <= 6.5:
    print("Học lực: Trung bình")
elif 0<= điểm <= 5:
    print("Học lực: Yếu")
# Out:
# Học lực: Giỏi

# %% [markdown]
# 8. Kiểm tra năm nhuận: Viết chương trình nhập năm, kiểm tra xem năm đó có phải
# năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4 nhưng không chia hết cho 100)

# %%
năm = int(input())
if năm%400==0 or năm%4==0 and năm%100!=0 :
    print("Năm nhuận")
else:
    print("Năm không nhuận")
# Out:
# Năm không nhuận

# %% [markdown]
# 9. Chuyển đổi số thành chữ số: Nhập một số nguyên từ 0 đến 9, in ra tên chữ số tương ứng (0 -> "Không", 1 -> "Một", ...) – Xem trước match …case

# %%
x= int(input())

match x:
    case 1:
        print("Một")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bốn")
    case 5:
        print("Năm")
    case 6:
        print("Sáu")
    case 7:
        print("Bảy")
    case 8:
        print("Tám")
    case 9:
        print("Chín")
# Out:
# Bốn

# %% [markdown]
# 10.Kiểm tra điểm thi xem có qua môn hay phải học lại: Nhập điểm thi, nếu điểm >= 4 thì in "Qua môn", ngược lại in "Học lại".

# %%
x= float(input("Nhập điêm thi:"))
if x >= 4:
    print("Qua môn")
else:
    print("Học lại")
# Out:
# Qua môn

# %% [markdown]
# 11.Kiểm tra năm sinh và tính tuổi: Nhập năm sinh, tính tuổi hiện tại (giả sử năm hiện tại là 2025), và kiểm tra xem người đó có đủ 18 tuổi hay chưa.

# %%
x= int(input("Năm sinh:"))
p= 2025-x
if p>= 18:
    print("Đủ 18 tuổi")
else:
    print("Chưa đủ 18 tuổi")
# Out:
# Chưa đủ 18 tuổi
